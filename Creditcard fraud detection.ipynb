# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\91789\Downloads\archive (5).zip")
df
#creditcard fraud detection
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
sns.boxplot(data=df,x="Class",y="Amount",hue="Class",showfliers=True,ax=None)
# Out:
# <Axes: xlabel='Class', ylabel='Amount'>

# %%
sns.boxplot(data=df,x="Class",y="Amount",showfliers=False,ax=None)
# Out:
# <Axes: xlabel='Class', ylabel='Amount'>

# %%
#### Observations:
- The first plot shows the transaction amounts including outliers, the second without outliers.
- From the second plot, we can see that fraudulent transactions have a lower median value.
- Fraudulent transactions also have a greater interquartile range.
- There are no fraudulent transactions for over 3000, so very large transactions are unlikely to be fraudulent.

# %%
sns.scatterplot(data=df.loc[df['Class']==0],x='Time',y='Amount')
plt.ylim(0,3000)
# Out:
# (0.0, 3000.0)

# %%
sns.scatterplot(data=df.loc[df['Class']==1],x='Time',y='Amount')
plt.title("transaction distribution over time")
plt.ylim(0,3000)
# Out:
# (0.0, 3000.0)

# %%
 Observations:
- By just looking at the amount and time, fraudulent transactions appear to be very well hidden amongst the noise of non-fraudulent transactions.

# %%
sns.heatmap(df.corr('pearson'))
# Out:
# <Axes: >

# %%
- The PCA features have little to no inter-correlation.
- Most of the PCA features correlate weakly with the transaction time, transaction amount, or both.
- It's likely we can largely reduce the size of this dataset, greatly reducing the number of features.

# %%
target variable = Class(y)
0 indicates a non-fraudulent transaction.
1 indicates a fraudulent transaction.
The dataset is highly imbalanced, meaning there are far more non-fraudulent transactions (Class = 0) than fraudulent ones (Class = 1)

# %%
To check if your data is balanced or not, you need to examine the distribution of the target variable (class labels

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
splitting data into features and target

# %%
X=df.drop(['Class','Time'],axis=1)
y=df['Class']
X
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
X.shape
# Out:
# (284807, 29)

# %%
y.shape
# Out:
# (284807,)

# %%
both rows are same

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.5,random_state=42)

# %%
X_train
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 102120 -4.565781  2.891870 -1.505909 -0.609598 -0.684404 -0.417628  0.093167
# 147630 -1.932119  0.463690 -1.171450 -0.549980  1.710455 -1.030608  1.084965
# 243316 -0.657832  0.753651  1.229142 -0.180336 -0.355564 -0.479811 -0.106428
# 259221 -1.207027  1.737476 -0.948094 -0.456881  0.686600 -0.665881  0.405398
# 144969  1.974552  0.176499 -2.080724  1.149523  0.845438 -0.908770  0.815385
# ...          ...       ...       ...       ...       ...       ...       ...
# 119879  1.173488  0.100792  0.490512  0.461596 -0.296377 -0.213165 -0.165254
# 259178 -0.775981  0.144023 -1.142399 -1.241113  1.940358  3.912076 -0.466107
# 131932 -0.146609  0.992946  1.524591  0.485774  0.349308 -0.815198  1.076640
# 146867 -2.948638  2.354849 -2.521201 -3.798905  1.866302  2.727695 -0.471769
# 121958  1.233174 -0.784851  0.386784 -0.698559 -1.034018 -0.637028 -0.502369
#
# ...

# %%
X_test
# Out:
#                V1        V2         V3        V4         V5        V6  \
# 43428  -16.526507  8.584972 -18.649853  9.505594 -13.793819 -2.832404
# 49906    0.339812 -2.743745  -0.134070 -1.385729  -1.451413  1.015887
# 29474    1.399590 -0.590701   0.168619 -1.029950  -0.539806  0.040444
# 276481  -0.432071  1.647895  -1.669361 -0.349504   0.785785 -0.630647
# 278846   2.014160 -0.137394  -1.015839  0.327269  -0.182179 -0.956571
# ...           ...       ...        ...       ...        ...       ...
# 104739  -2.431366  2.360288   0.786640  0.164614   0.368304 -0.333723
# 35759    0.995305 -0.188769   1.183485  2.694444  -0.303485  1.631109
# 133504  -1.127203  0.354516   2.116713  0.234350   1.210980 -0.096051
# 32956   -1.764537  1.167009   0.661267  0.036640  -0.647161  0.666344
# 195585  -5.878929  5.529564  -4.419541 -2.114291  -1.004907 -1.730706
#
#                V7        V8        V9        V10  ...       V20       V21  \
# ...

# %%
y_train
# Out:
# 102120    0
# 147630    0
# 243316    0
# 259221    0
# 144969    0
#          ..
# 119879    0
# 259178    0
# 131932    0
# 146867    0
# 121958    0
# Name: Class, Length: 142403, dtype: int64

# %%
y_test
# Out:
# 43428     1
# 49906     0
# 29474     0
# 276481    0
# 278846    0
#          ..
# 104739    0
# 35759     0
# 133504    0
# 32956     0
# 195585    0
# Name: Class, Length: 142404, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model
# Out:
# LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
evaluate the model

# %%
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array([1, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from the above training set,we got to know that transaction  1 is fraudulent

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    142158
#            1       0.86      0.62      0.72       246
#
#     accuracy                           1.00    142404
#    macro avg       0.93      0.81      0.86    142404
# weighted avg       1.00      1.00      1.00    142404

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9992158515033414
